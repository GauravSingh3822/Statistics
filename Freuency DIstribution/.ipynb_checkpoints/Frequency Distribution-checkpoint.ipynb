# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset("mpg")

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# Ungrouoed frequency

# %%
data["origin"].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
data["origin"].value_counts().plot(kind="bar")
plt.title("Bar_Graph")
plt.xlabel("Origin")
plt.ylabel("Numbers")

plt.show()

# %%
data["model_year"].value_counts()

data["model_year"].value_counts().plot(kind="bar")
plt.title("Bar_Graph")
plt.xlabel("Origin")
plt.ylabel("Numbers")

plt.show()

# %%
pd.crosstab(data["origin"],"Number of cars")
# Out:
# col_0   Number of cars
# origin
# europe              70
# japan               79
# usa                249

# %%
pd.crosstab(data["origin"],data["model_year"])
# Out:
# model_year  70  71  72  73  74  75  76  77  78  79  80  81  82
# origin
# europe       5   4   5   7   6   6   8   4   6   4   9   4   2
# japan        2   4   5   4   6   4   4   6   8   2  13  12   9
# usa         22  20  18  29  15  20  22  18  22  23   7  13  20

# %% [markdown]
# Relative Frequency

# %%
cars_in_country=pd.crosstab(data["origin"],"Number of cars")

# %%
cars_in_country["relative frequency"]=cars_in_country["Number of cars"]/sum(cars_in_country["Number of cars"])

# %%
cars_in_country
# Out:
# col_0   Number of cars  relative frequency
# origin
# europe              70            0.175879
# japan               79            0.198492
# usa                249            0.625628

# %% [markdown]
# Percentage Frequency

# %%
cars_in_country["Percentage Frequency"]=cars_in_country["relative frequency"]*100

# %%
cars_in_country
# Out:
# col_0   Number of cars  relative frequency  Percentage Frequency
# origin
# europe              70            0.175879             17.587940
# japan               79            0.198492             19.849246
# usa                249            0.625628             62.562814

# %%
data["origin"].value_counts().plot(kind='pie', autopct="%1.f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Grouped Frequency

# %%
data["displacement"].value_counts(bins=5)
# Out:
# (67.612, 145.4]    196
# (300.2, 377.6]      73
# (222.8, 300.2]      60
# (145.4, 222.8]      44
# (377.6, 455.0]      25
# Name: count, dtype: int64

# %%
plt.hist(data["displacement"],bins=5)
plt.show()

# %%
data[(data["weight"]>4787.3) & (data["weight"]<5140.1)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 42   12.0          8         383.0       180.0    4955          11.5
# 44   13.0          8         400.0       175.0    5140          12.0
# 90   12.0          8         429.0       198.0    4952          11.5
# 95   12.0          8         455.0       225.0    4951          11.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 104  12.0          8         400.0       167.0    4906          12.5
#
#      model_year origin                      name
# 42           71    usa         dodge monaco (sw)
# 44           71    usa       pontiac safari (sw)
# 90           73    usa  mercury marquis brougham
# 95           73    usa  buick electra 225 custom
# 103          73    usa          chevrolet impala
# 104          73    usa              ford country

# %%
data.sort_values("weight",ascending=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 44   13.0          8         400.0       175.0    5140          12.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 42   12.0          8         383.0       180.0    4955          11.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 95   12.0          8         455.0       225.0    4951          11.0
# ..    ...        ...           ...         ...     ...           ...
# 53   31.0          4          71.0        65.0    1773          19.0
# 345  35.1          4          81.0        60.0    1760          16.1
# 343  39.1          4          79.0        58.0    1755          16.9
# 144  31.0          4          76.0        52.0    1649          16.5
# 54   35.0          4          72.0        69.0    1613          18.0
#
#      model_year origin                      name
# 44           71    usa       pontiac safari (sw)
# ...

# %%
data["weight"].value_counts(bins=10,sort=False).plot(kind="barh")
# Out:
# <Axes: >
